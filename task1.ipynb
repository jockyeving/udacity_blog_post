# %%
import pandas as pd

from util.task1_utils import languages_by_column, merge_results, plot_result

# %%
df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
# Getting the number of people working/wanting to work on different programming languages
result1 = languages_by_column(df, 'HaveWorkedLanguage')
result2 = languages_by_column(df, 'WantWorkLanguage')
result = merge_results(result1, result2)
result.sort_values(by=['HaveWorkedLanguage'], inplace = True)
result
# Out:
#            HaveWorkedLanguage WantWorkLanguage
# Rust                      416             2718
# R                        1634             2628
# Assembly                 1823             1923
# Ruby                     3324             3966
# C++                      8155             7647
# C                        8555             6183
# PHP                     10290             5365
# Python                  11704            12570
# C#                      12476            10187
# Java                    14524             9988
# SQL                     18754            11217
# JavaScript              22875            16327

# %%
# Plotting the results side by side, sorted by current workers of each
plot_result(result)
